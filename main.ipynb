# %%
import pandas as pd

df = pd.read_csv('Preload_simulation_data/Candidate1.csv', skiprows=1)
df.head()
df.columns = ['Candidate', 'PUL Preload', 'Muscle Preload', 'Moment X', 'Moment Total', 'Total def Max', 'Total def Av', 'PUL Preload (2)', 'PUL Zone def Sup Max', 'Muscle Zone def Sup Max', 'Muscle Zone def Pos Max', 'PUL Zone def Pos Max', 'PUL Zone def Sup Min', 'Muscle Zone def Sup Min', 'Muscle Zone def Pos Min', 'PUL Zone def Pos Min']
# Out:
#               # Name  \
# 0               Name
# 1  Candidate Point 1
# 2  Candidate Point 2
# 3  Candidate Point 3
# 4  Candidate Point 4
#
#   P15 - Longitudinal - PUL_X=Y 1 body muscle along(Mechanical Model) To Solid(Mechanical Model) Load (N)   \
# 0                                                P15
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#   P17 - Longitudinal - PUL_X=Y 1 body muscle along(Mechanical Model) To Solid(Mechanical Model) Load (N)   \
# 0                                                P17
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  5
#
#   P1 - Moment Reaction Maximum X Axis (N m)   \
# 0                                         P1
# 1                      0.0012738120840181829
# 2                    -0.00010284282724612875
# 3                    -0.00047548483241634622
# 4                       0.000759832766123101
#
#   P2 - Moment Reaction Maximum Total (N m)   \
# 0                                        P2
# 1                     0.0012895038934516883
# 2                    0.00046882979628612193
# 3                     0.0021706837501412929
# 4                    0.00082296774182587869
#
#   P3 - Total Deformation Maximum (m)  P4 - Total Deformation Average (m)   \
# 0                                  P3                                  P4
# 1               0.0011402236923912824              0.00033601719213045329
# 2               0.0014230318042388202                0.000337011888745622
# 3               0.0019663494497923766              0.00044673083910257871
# 4                 0.00203032201091316              0.00057570748860915006
#
#   P16 - Longitudinal - PUL_X=Y 1 body muscle along(Mechanical Model) To Solid(Mechanical Model) Load (N)   \
# 0                                                P16
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#   P18 - Y_directional_deformation_PUL Maximum (mm)   \
# 0                                               P18
# 1                               0.98881697654724132
# 2                               0.90681225061416626
# 3                               0.82943028211593628
# 4                                1.7074871063232422
#
#   P19 - Y_directional_deformation_Muscle Maximum (mm)   \
# 0                                                P19
# 1                                0.98881697654724132
# 2                                0.90681225061416626
# 3                                0.82943028211593628
# 4                                 1.7074871063232422
#
#   P20 - Z_directional_deformation_Muscle Maximum (mm)   \
# 0                                                P20
# 1                                0.24791963398456573
# 2                                0.92928588390350342
# 3                                 1.6483621597290039
# 4                                0.99010640382766713
#
#   P21 - Z_directional_deformation_PUL Maximum (mm)   \
# 0                                               P21
# 1                                 0.680645227432251
# 2                                1.2797811031341553
# 3                                  1.89116370677948
# 4                                1.5959833860397339
#
#   P22 - Y_directional_deformation_PUL Minimum (mm)   \
# 0                                               P22
# 1                               0.39053234457969666
# 2                               0.29051920771598816
# 3                                0.1808745414018631
# 4                               0.68788838386535645
#
#   P23 - Y_directional_deformation_Muscle Minimum (mm)   \
# 0                                                P23
# 1                                                  0
# 2                                                  0
# 3                               -0.11696542054414749
# 4                                                  0
#
#   P24 - Z_directional_deformation_Muscle Minimum (mm)   \
# 0                                                P24
# 1                                -1.0580859184265137
# 2                                 -0.754504919052124
# 3                               -0.49813711643218989
# 4                                -1.5533220767974854
#
#   P25 - Z_directional_deformation_PUL Minimum (mm)
# 0                                               P25
# 1                              -0.25319954752922058
# 2                               0.41889995336532593
# 3                                1.0617548227310181
# 4                               0.17101223766803741
